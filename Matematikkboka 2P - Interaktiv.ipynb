mal og spredningsmal</a><ul><li><a href="#5.1-Gjennomsnitt-og-typetall">5.1 Gjennomsnitt og typetall</a></li><li><a href="#5.2-Median">5.2 Median</a></li><li><a href="#5.3-Median-i-frekvenstabell">5.3 Median i frekvenstabell</a></li><li><a href="#5.4-Variasjonsbredde-og-standardavvik">5.4 Variasjonsbredde og standardavvik</a></li><li><a href="#5.5-Vurdering-av-sentralmal-og-spredningsmal">5.5 Vurdering av sentralmal og spredningsmal</a></li><li><a href="#5.6-Sentralmal-i-gruppert-materiale">5.6 Sentralmal i gruppert materiale</a></li></ul></li><li><a href="#6-Geometri">6 Geometri</a><ul><li><a href="#6.1-Vinkler-i-formlike-figurer">6.1 Vinkler i formlike figurer</a></li><li><a href="#6.2-Lengder-i-formlike-figurer">6.2 Lengder i formlike figurer</a></li><li><a href="#6.3-Pytagorassetningen">6.3 Pytagorassetningen</a></li><li><a href="#6.4-Malestokk">6.4 Malestokk</a></li><li><a href="#6.5-Areal-og-omkrets">6.5 Areal og omkrets</a></li><li><a href="#6.6-Prisme-og-sylinder">6.6 Prisme og sylinder</a></li><li><a href="#6.7-Kule">6.7 Kule</a></li></ul></li></ul>

# %% [markdown]
# <h1 id="0-Systemsjekk-og-kalender">0 Systemsjekk og kalender</h1>

# %% [markdown]
# <h2 id="0.1-Systemsjekk">0.1 Systemsjekk</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %%
import sys
print(sys.version)

# %% [markdown]
# <h2 id="0.2-Kalender">0.2 Kalender</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %%
import calendar
from datetime import date

def display_calendar():
    year = int(input("Skriv år: "))
    month = int(input("Skriv måned (1-12): "))

    cal = calendar.TextCalendar(calendar.MONDAY)
    
    # Print the month calendar
    month_calendar = cal.formatmonth(year, month)
    print(month_calendar)

    # Print week numbers
    print("Ukenumre:")
    month_weeks = cal.monthdayscalendar(year, month)
    for week in month_weeks:
        # Find the first day of the week that is not 0 (which means no day)
        first_day = next((day for day in week if day != 0), None)
        if first_day:
            week_number = date(year, month, first_day).isocalendar()[1]
            print(f"Uke {week_number}: {week}")

display_calendar()

# %% [markdown]
# <a href="#1-Prosent">➡ Neste kapittel</a>

# %% [markdown]
# <h1 id="1-Prosent">1 Prosent</h1>

# %% [markdown]
# <h2 id="1.0-Grunnleggende-regning">1.0 Grunnleggende regning</h2>
# <p><em>Forklare og bruke prosent, prosentpoeng og vekstfaktor til modellering av praktiske situasjoner med digitale verktøy</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="1.1-Prosentregning">1.1 Prosentregning</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="1.2-Prosentpoeng">1.2 Prosentpoeng</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="1.3-Vekstfaktor">1.3 Vekstfaktor</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="1.4-Eksponentiell-vekst">1.4 Eksponentiell vekst</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="1.5-Eksponentiell-regresjon">1.5 Eksponentiell regresjon</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h1 id="2-Likninger-og-ulikheter">2 Likninger og ulikheter</h1>

# %% [markdown]
# <h2 id="2.1-Likninger">2.1 Likninger</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="2.2-Lose-likninger-ved-regning">2.2 Lose likninger ved regning</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="2.3-Uoppsatte-likninger">2.3 Uoppsatte likninger</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="2.4-Grafisk-losning-av-likninger">2.4 Grafisk losning av likninger</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="2.5-Likningssett">2.5 Likningssett</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="2.6-Ulikheter">2.6 Ulikheter</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h1 id="3-Okonomi">3 Okonomi</h1>

# %% [markdown]
# <h2 id="3.1-Prisindekser">3.1 Prisindekser</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="3.2-Konsumprisindeks">3.2 Konsumprisindeks</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="3.3-Kronerverd-og-nettolonn">3.3 Kronerverd og nettolonn</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="3.4-Bruttolonn-og-nettolonn">3.4 Bruttolonn og nettolonn</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="3.5-Sparing">3.5 Sparing</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="3.6-Lan">3.6 Lan</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="3.7-Kredittkort">3.7 Kredittkort</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="3.8-Okonomiske-valg">3.8 Okonomiske valg</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h1 id="4-Statistikk-analyse-og-presentasjon">4 Statistikk analyse og presentasjon</h1>

# %% [markdown]
# <h2 id="4.1-Lese-tabeller-og-diagrammer">4.1 Lese tabeller og diagrammer</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="4.2-Lage-sylediagrammer">4.2 Lage sylediagrammer</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="4.3-Lage-sektordiagrammer">4.3 Lage sektordiagrammer</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="4.4-Lage-linjediagrammer">4.4 Lage linjediagrammer</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="4.5-Forsterke-informasjon">4.5 Forsterke informasjon</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="4.6-Lage-histogrammer">4.6 Lage histogrammer</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h1 id="5-Sentralmal-og-spredningsmal">5 Sentralmal og spredningsmal</h1>

# %% [markdown]
# <h2 id="5.1-Gjennomsnitt-og-typetall">5.1 Gjennomsnitt og typetall</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="5.2-Median">5.2 Median</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="5.3-Median-i-frekvenstabell">5.3 Median i frekvenstabell</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="5.4-Variasjonsbredde-og-standardavvik">5.4 Variasjonsbredde og standardavvik</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="5.5-Vurdering-av-sentralmal-og-spredningsmal">5.5 Vurdering av sentralmal og spredningsmal</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="5.6-Sentralmal-i-gruppert-materiale">5.6 Sentralmal i gruppert materiale</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h1 id="6-Geometri">6 Geometri</h1>

# %% [markdown]
# <h2 id="6.1-Vinkler-i-formlike-figurer">6.1 Vinkler i formlike figurer</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="6.2-Lengder-i-formlike-figurer">6.2 Lengder i formlike figurer</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="6.3-Pytagorassetningen">6.3 Pytagorassetningen</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="6.4-Malestokk">6.4 Malestokk</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="6.5-Areal-og-omkrets">6.5 Areal og omkrets</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="6.6-Prisme-og-sylinder">6.6 Prisme og sylinder</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>

# %% [markdown]
# <h2 id="6.7-Kule">6.7 Kule</h2>
# <p><em>Fyll inn innhold her</em></p>
#
# <a href="#Innholdsfortegnelse">⬆ Tilbake til innholdsfortegnelse</a>
